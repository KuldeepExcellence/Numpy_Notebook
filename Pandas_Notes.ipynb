# %%
import pandas as pd
pd
# Out:
# <module 'pandas' from '/opt/anaconda3/lib/python3.12/site-packages/pandas/__init__.py'>

# %%
sr1 = pd.Series([1,2,4,22,3,4,4,3,2,4])
sr1
# Out:
# 0     1
# 1     2
# 2     4
# 3    22
# 4     3
# 5     4
# 6     4
# 7     3
# 8     2
# 9     4
# dtype: int64

# %%
data = { "one" :[0.1,1.1,2.1],
        "two":[0.2,1.2,2.2]
}

df1 = pd.DataFrame(data,index=["num1","num2","num3"])
df1
# Out:
#       one  two
# num1  0.1  0.2
# num2  1.1  1.2
# num3  2.1  2.2

# %%
# df1.loc[2]
df1.loc["num1":"num2","one":"two"]
# Out:
#       one  two
# num1  0.1  0.2
# num2  1.1  1.2

# %%
import pandas as pd

# %%
data = pd.read_csv("netflix_dataset.csv")

# %%
data.loc[0:100,"Show_Id":"Cast"]
# Out:
#     Show_Id Category           Title           Director  \
# 0        s1  TV Show              3%                NaN
# 1        s2    Movie           07:19  Jorge Michel Grau
# 2        s3    Movie           23:59       Gilbert Chan
# 3        s4    Movie               9        Shane Acker
# 4        s5    Movie              21     Robert Luketic
# ..      ...      ...             ...                ...
# 96      s97    Movie  3 Days to Kill                McG
# 97      s98    Movie     3 Deewarein    Nagesh Kukunoor
# 98      s99    Movie   3 Generations        Gaby Dellal
# 99     s100    Movie      3 Heroines     Iman Brotoseno
# 100    s101    Movie        3 Idiots    Rajkumar Hirani
#
#                                                   Cast
# 0    João Miguel, Bianca Comparato, Michel Gomes, R...
# 1    Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2    Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3    Elijah Wood, John C. Reilly, Jennifer Connelly...
# ...

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data.tail()
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %%
data = pd.read_json("sample4.json")

# %%
data.loc[1:]
# Out:
#                                               people
# 1  {'firstName': 'James', 'lastName': 'Smith', 'g...
# 2  {'firstName': 'Emily', 'lastName': 'Jones', 'g...

# %%
data = pd.read_csv("exercise_data.csv")

# %%
data
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
# To Delete the Rows that have any None Data 
# This will create a new
# df = data.dropna()
df = data

# %%
# df2=df.fillna(11211)

# %%
df3 = df.fillna({"Calories":500.11,"Date":"1 Jan 2025"})

# %%
df3
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130    409.10
# 1         60  '2020/12/02'    117       145    479.00
# 2         60  '2020/12/03'    103       135    340.00
# 3         45  '2020/12/04'    109       175    282.40
# 4         45  '2020/12/05'    117       148    406.00
# 5         60  '2020/12/06'    102       127    300.00
# 6         60  '2020/12/07'    110       136    374.00
# 7        450  '2020/12/08'    104       134    253.30
# 8         30  '2020/12/09'    109       133    195.10
# 9         60  '2020/12/10'     98       124    269.00
# 10        60  '2020/12/11'    103       147    329.30
# 11        60  '2020/12/12'    100       120    250.70
# 12        60  '2020/12/12'    100       120    250.70
# 13        60  '2020/12/13'    106       128    345.30
# 14        60  '2020/12/14'    104       132    379.30
# 15        60  '2020/12/15'     98       123    275.00
# ...

# %%
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
x=df["Calories"].mean()

# %%
df4 = df.fillna({"Calories":x})

# %%
x
# Out:
# 304.68

# %%
print(df4)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130    409.10
# 1         60  '2020/12/02'    117       145    479.00
# 2         60  '2020/12/03'    103       135    340.00
# 3         45  '2020/12/04'    109       175    282.40
# 4         45  '2020/12/05'    117       148    406.00
# 5         60  '2020/12/06'    102       127    300.00
# 6         60  '2020/12/07'    110       136    374.00
# 7        450  '2020/12/08'    104       134    253.30
# 8         30  '2020/12/09'    109       133    195.10
# 9         60  '2020/12/10'     98       124    269.00
# 10        60  '2020/12/11'    103       147    329.30
# 11        60  '2020/12/12'    100       120    250.70
# 12        60  '2020/12/12'    100       120    250.70
# 13        60  '2020/12/13'    106       128    345.30
# 14        60  '2020/12/14'    104       132    379.30
# 15        60  '2020/12/15'     98       123    275.00
# ...

# %%
df["Calories"].median()
# Out:
# 291.2

# %%
import pandas as pd
pd
# Out:
# <module 'pandas' from '/opt/anaconda3/lib/python3.12/site-packages/pandas/__init__.py'>

# %%
data = pd.read_csv("exercise_data.csv")

# %%
data[0:7,"Date"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: (slice(0, 7, None), 'Date')
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 data[0:7,"Date"]
#
# ...

# %%
import csv
file = open("students.csv")
reader = csv.reader(file)
for i in reader:
    print(i)

print()
file = open("students.csv")
reader = csv.reader(file)
for i in reader:
    for j in i :
        print(j,"  |  ",end=" ")
    print()


print()
file = open("students.csv")
reader = csv.reader(file)
for i in reader:
    for j in i :
        print(j," "*(10-len(j)),"|",end="     ")
    print()
# Out:
# ['Name', 'Age', 'City']
# ['Kuldeep', '26', 'Delhi']
# ['Anita', '23', 'Mumbai']
# ['Rohan', '24', 'Bangalore']
# ['Priya', '22', 'Chandigarh']
# ['Vikram', '25', 'Pune']
# ['Simran', '21', 'Ludhiana']
# ['Arjun', '27', 'Hyderabad']
# ['Neha', '24', 'Jaipur']
# ['Karan', '23', 'Kolkata']
# ['Meera', '22', 'Chennai']
#
# Name   |   Age   |   City   |
# Kuldeep   |   26   |   Delhi   |
# Anita   |   23   |   Mumbai   |
# Rohan   |   24   |   Bangalore   |
# Priya   |   22   |   Chandigarh   |
# Vikram   |   25   |   Pune   |
# Simran   |   21   |   Ludhiana   |
# Arjun   |   27   |   Hyderabad   |
# Neha   |   24   |   Jaipur   |
# Karan   |   23   |   Kolkata   |
# Meera   |   22   |   Chennai   |
#
# Name        |     Age         |     City        |
# Kuldeep     |     26          |     Delhi       |
# Anita       |     23          |     Mumbai      |
# Rohan       |     24          |     Bangalore   |
# Priya       |     22          |     Chandigarh  |
# ...

# %%
# file = open("students.csv")
# print(file.read())

import csv
li = [["Kuldeep,26,Delhi"],["Anita,23,Mumbai"],["Rohan,24,Bangalore"]]
file = open("shravan.csv", "w")
writer = csv.writer(file)
writer. writeLines(li)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[43], line 8
#       6 file = open("shravan.csv", "w")
#       7 writer = csv.writer(file)
# ----> 8 writer. writeLines(li)
#
# AttributeError: '_csv.writer' object has no attribute 'writeLines'

# %%
file = open("students.csv")
reader = csv.reader(file)
for i in reader:
    for j in i :
        print(j," "*(10-len(j)),"|",end="     ")
    print()
# Out:
# Name        |     Age         |     City        |
# Kuldeep     |     26          |     Delhi       |
# Anita       |     23          |     Mumbai      |
# Rohan       |     24          |     Bangalore   |
# Priya       |     22          |     Chandigarh  |
# Vikram      |     25          |     Pune        |
# Simran      |     21          |     Ludhiana    |
# Arjun       |     27          |     Hyderabad   |
# Neha        |     24          |     Jaipur      |
# Karan       |     23          |     Kolkata     |
# Meera       |     22          |     Chennai     |

# %%
file = open("students.csv""r")
reader =
